# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
ecg_dataset = pd.read_csv("ecg_autoencoder_dataset.csv")

# %%
# Preprocess the data
scaler = StandardScaler()
X = scaler.fit_transform(ecg_dataset.values)
y = X  # Autoencoder input and output are the same

X_train, X_test, _, _ = train_test_split(X, X, test_size=0.2, random_state=42)

# %%
# Build and train the Autoencoder model
input_dim = X_train.shape[1]

# %% [markdown]
# # c. Encoder converts it into latent representation

# %%
encoder = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(8, activation='relu')
])

# %% [markdown]
# # d. Decoder networks convert it back to the original input

# %%
decoder = models.Sequential([
    layers.Input(shape=(8,)),
    layers.Dense(16, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(input_dim, activation='linear')  # Use linear activation for reconstruction
])

# %% [markdown]
# # e. Compile the models with Optimizer, Loss, and Evaluation Metrics

# %%
autoencoder = models.Sequential([
    encoder,
    decoder
])
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, shuffle=True)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 1s 1ms/step - loss: 0.6793
# Epoch 2/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.3593
# Epoch 3/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2839
# Epoch 4/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2514
# Epoch 5/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2304
# Epoch 6/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2140
# Epoch 7/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2038
# Epoch 8/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1960
# Epoch 9/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1886
# Epoch 10/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1814
# Epoch 11/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1718
# Epoch 12/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1645
# Epoch 13/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1611
# Epoch 14/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1569
# Epoch 15/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1527
# Epoch 16/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1495
# Epoch 17/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1459
# Epoch 18/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1427
# Epoch 19/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1398
# Epoch 20/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1375
# Epoch 21/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1357
# Epoch 22/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1338
# Epoch 23/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1333
# Epoch 24/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1317
# Epoch 25/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1305
# Epoch 26/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1293
# Epoch 27/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1281
# Epoch 28/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1272
# Epoch 29/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1257
# Epoch 30/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1254
# Epoch 31/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1246
# Epoch 32/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1230
# Epoch 33/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1222
# Epoch 34/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1220
# Epoch 35/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1206
# Epoch 36/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1201
# Epoch 37/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1191
# Epoch 38/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1190
# Epoch 39/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1185
# Epoch 40/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1170
# Epoch 41/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1164
# Epoch 42/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1161
# Epoch 43/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1159
# Epoch 44/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1155
# Epoch 45/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1149
# Epoch 46/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1143
# Epoch 47/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1136
# Epoch 48/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1128
# Epoch 49/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1132
# Epoch 50/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1125
# Epoch 51/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1130
# Epoch 52/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1126
# Epoch 53/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1117
# Epoch 54/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1114
# Epoch 55/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1113
# Epoch 56/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1114
# Epoch 57/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1110
# Epoch 58/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1105
# Epoch 59/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1098
# Epoch 60/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1088
# Epoch 61/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1087
# Epoch 62/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1086
# Epoch 63/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1080
# Epoch 64/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1075
# Epoch 65/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1079
# Epoch 66/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1073
# Epoch 67/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1073
# Epoch 68/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1066
# Epoch 69/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1062
# Epoch 70/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1060
# Epoch 71/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1058
# Epoch 72/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1056
# Epoch 73/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1049
# Epoch 74/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1040
# Epoch 75/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1040
# Epoch 76/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1029
# Epoch 77/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1022
# Epoch 78/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1024
# Epoch 79/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1024
# Epoch 80/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1010
# Epoch 81/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1011
# Epoch 82/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1005
# Epoch 83/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1001
# Epoch 84/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1000
# Epoch 85/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1003
# Epoch 86/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0989
# Epoch 87/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0983
# Epoch 88/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0983
# Epoch 89/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0974
# Epoch 90/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0971
# Epoch 91/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0966
# Epoch 92/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0965
# Epoch 93/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0961
# Epoch 94/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0961
# Epoch 95/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0953
# Epoch 96/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0958
# Epoch 97/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0944
# Epoch 98/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0942
# Epoch 99/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0941
# Epoch 100/100
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0931

# %%
# Detect anomalies
y_pred = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - y_pred, 2), axis=1)
# Out:
# 32/32 [==============================] - 0s 1ms/step

# %%
# Define a threshold for anomaly detection
threshold = np.percentile(mse, 95)  # Adjust the percentile as needed

# %%
# Predict anomalies
anomalies = mse > threshold

# %%
# Calculate the number of anomalies
num_anomalies = np.sum(anomalies)
print(f"Number of Anomalies: {num_anomalies}")
# Out:
# Number of Anomalies: 50

# %%
# Plot the anomalies
plt.figure(figsize=(12, 6))
plt.plot(mse, marker='o', linestyle='', markersize=3, label='MSE')
plt.axhline(threshold, color='r', linestyle='--', label='Anomaly Threshold')
plt.xlabel('Sample Index')
plt.ylabel('MSE')
plt.title('Anomaly Detection Results')
plt.legend()
plt.show()

# %% [markdown]
# # Visualize Normal

# %%
plt.figure(figsize=(12, 6))
plt.plot(X_test[0], label='Original ECG')
plt.plot(y_pred[0], label='Reconstructed ECG')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.title('Normal ECG')
plt.show()

# %% [markdown]
# # Visualize Anomaly

# %%
# listing the index of anomalies in X_test
anomalies_index = []
for index, anomaly in enumerate(anomalies):
    if anomaly == True :
        anomalies_index.append(index)
n = 4
anomaly_index = anomalies_index[n]
plt.figure(figsize=(12, 6))
plt.plot(X_test[anomaly_index], label='Original ECG')
plt.plot(y_pred[anomaly_index], label='Reconstructed ECG')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.title('ECG and Anomalies')
plt.show()

# %%
# Evaluate the model
y_true = np.zeros(len(X_test))
print("Confusion Matrix:")
print(confusion_matrix(anomalies, anomalies))

print("\nClassification Report:")
print(classification_report(anomalies, anomalies))
# Out:
# Confusion Matrix:
# [[950   0]
#  [  0  50]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       950
#         True       1.00      1.00      1.00        50
#
#     accuracy                           1.00      1000
#    macro avg       1.00      1.00      1.00      1000
# weighted avg       1.00      1.00      1.00      1000

# %%
import seaborn as sns
plt.figure(figsize = (6, 4.75))
sns.heatmap(confusion_matrix(anomalies, anomalies), annot = True, annot_kws = {"size": 16}, fmt = 'd')
plt.xticks([0.5, 1.5],  rotation = 'horizontal')
plt.yticks([0.5, 1.5],  rotation = 'horizontal')
plt.xlabel("Predicted label", fontsize = 14)
plt.ylabel("True label", fontsize = 14)
plt.title("Confusion Matrix", fontsize = 14)
plt.grid(False)
plt.show()
